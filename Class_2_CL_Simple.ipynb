# %% [markdown]
# <a href="https://colab.research.google.com/github/birukethio/SEAS8525/blob/main/Class_2_CL_Simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# The SimCLR approach aims to learn meaningful representations of images in a self-supervised manner. It does this by maximizing the cosine similarity between representations of augmented views of the same image (positive pairs) and minimizing the cosine similarity between representations of different images (negative pairs). The contrastive loss encourages the encoder to learn representations that are invariant to the applied data augmentations.
#
# The visualization using t-SNE allows us to assess the quality of the learned representations by observing how well the different classes are separated in the low-dimensional space.

# %% [markdown]
# This code demonstrates the implementation of a self-supervised learning approach called SimCLR (Simple Framework for Contrastive Learning of Visual Representations) using the CIFAR-10 dataset. Let's go through the code section by section:
#
# 1. Importing Libraries:
#    - The necessary libraries, including TensorFlow, Keras, Matplotlib, and scikit-learn, are imported.
#
# 2. Loading and Preprocessing Data:
#    - The CIFAR-10 dataset is loaded using `keras.datasets.cifar10.load_data()`.
#    - The pixel values of the training and testing data are normalized to the range [0, 1].
#    - The training data is converted into a TensorFlow Dataset using `tf.data.Dataset.from_tensor_slices()` and batched.
#
# 3. Data Augmentation:
#    - A data augmentation pipeline is defined using `keras.Sequential()` to apply random cropping, flipping, rescaling, and zooming to the input images.
#
# 4. Defining the Encoder Network:
#    - The `create_encoder` function defines the base encoder network using convolutional layers, max pooling, and a global max pooling layer.
#    - The encoder network takes an input image and outputs a 128-dimensional feature representation.
#
# 5. Defining the Projection Head:
#    - The `create_projection_head` function defines the projection head network using dense layers.
#    - The projection head takes the 128-dimensional feature representation from the encoder and projects it to a 128-dimensional space.
#
# 6. Training Loop:
#    - The training loop runs for a specified number of epochs.
#    - For each batch of training data:
#      - The encoder and projection head are applied to the batch of images.
#      - The resulting projected representations are L2-normalized.
#      - The cosine similarity matrix is computed between the normalized representations.
#      - The contrastive loss is calculated using the cosine similarity matrix and temperature scaling.
#      - The gradients of the loss with respect to the weights of the encoder and projection head are computed.
#      - The optimizer is used to update the weights of the encoder and projection head.
#
# 7. Extracting Representations:
#    - After training, the trained encoder is used to extract representations (embeddings) for the test images.
#
# 8. t-SNE Visualization:
#    - The t-SNE algorithm is used to reduce the dimensionality of the learned representations to 2D.
#    - The t-SNE results are plotted using Matplotlib, with each point colored according to its true class label.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# Load and preprocess the CIFAR-10 dataset
(x_train, _), (x_test, y_test) = keras.datasets.cifar10.load_data()
x_train, x_test = x_train.astype('float32') / 255.0, x_test.astype('float32') / 255.0

batch_size = 256

# Convert the training data into a TensorFlow Dataset
train_dataset = tf.data.Dataset.from_tensor_slices(x_train).batch(batch_size)

# Define the data augmentation function
data_augmentation = keras.Sequential([
    layers.RandomCrop(height=32, width=32),
    layers.RandomFlip("horizontal"),
    layers.Rescaling(1./255),
    layers.RandomZoom(0.2),
])

# Define the base encoder network
def create_encoder():
    inputs = layers.Input(shape=(32, 32, 3))
    x = data_augmentation(inputs)
    x = layers.Conv2D(32, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(64, 3, activation='relu')(x)
    x = layers.MaxPooling2D(2)(x)
    x = layers.Conv2D(128, 3, activation='relu')(x)
    x = layers.GlobalMaxPooling2D()(x)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

# Define the projection head
def create_projection_head():
    inputs = keras.Input(shape=(128,))
    x = layers.Dense(256, activation='relu')(inputs)
    outputs = layers.Dense(128)(x)
    return keras.Model(inputs=inputs, outputs=outputs)

encoder = create_encoder()
projection_head = create_projection_head()

optimizer = keras.optimizers.Adam()
batch_size = 256
epochs = 100
temperature = 0.1

# Custom training loop
for epoch in range(epochs):
    print(f"\nStart of epoch {epoch}")
    for step, x_batch_train in enumerate(train_dataset):
        with tf.GradientTape() as tape:
            # Forward pass
            encoded = encoder(x_batch_train, training=True)
            projected = projection_head(encoded, training=True)
            normalized = tf.math.l2_normalize(projected, axis=1)
            cosine_similarity = tf.matmul(normalized, normalized, transpose_b=True)
            logits = cosine_similarity / temperature
            labels = tf.range(x_batch_train.shape[0])
            loss_value = keras.losses.sparse_categorical_crossentropy(labels, logits, from_logits=True)
            loss_value = tf.reduce_mean(loss_value)

        # Get gradients of loss wrt the weights.
        gradients = tape.gradient(loss_value, encoder.trainable_weights + projection_head.trainable_weights)

        # Update the weights of the encoder and projection head.
        optimizer.apply_gradients(zip(gradients, encoder.trainable_weights + projection_head.trainable_weights))

        if step % 100 == 0:
            print(f"Training loss (for one batch) at step {step}: {float(loss_value)}")

# Extract representations after training
representations = encoder.predict(x_test)

# t-SNE visualization
tsne = TSNE(n_components=2, perplexity=30, n_iter=3000)
tsne_results = tsne.fit_transform(representations)

plt.figure(figsize=(8, 8))
plt.scatter(tsne_results[:, 0], tsne_results[:, 1], c=y_test.flatten(), cmap='rainbow')
plt.title('t-SNE Visualization of Learned Representations')
plt.colorbar()
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 4s 0us/step
#
# Start of epoch 0
# Training loss (for one batch) at step 0: 5.18787956237793
# Training loss (for one batch) at step 100: 1.6250782012939453
#
# Start of epoch 1
# Training loss (for one batch) at step 0: 0.41127052903175354
# Training loss (for one batch) at step 100: 0.18210139870643616
#
# Start of epoch 2
# Training loss (for one batch) at step 0: 0.10827037692070007
# Training loss (for one batch) at step 100: 0.08627114444971085
#
# Start of epoch 3
# Training loss (for one batch) at step 0: 0.0729251578450203
# Training loss (for one batch) at step 100: 0.06492115557193756
#
# Start of epoch 4
# Training loss (for one batch) at step 0: 0.05686628445982933
# Training loss (for one batch) at step 100: 0.05116894468665123
#
# Start of epoch 5
# Training loss (for one batch) at step 0: 0.04655727744102478
# Training loss (for one batch) at step 100: 0.04488978907465935
#
# Start of epoch 6
# Training loss (for one batch) at step 0: 0.0416925773024559
# Training loss (for one batch) at step 100: 0.04283759370446205
#
# Start of epoch 7
# Training loss (for one batch) at step 0: 0.037135932594537735
# Training loss (for one batch) at step 100: 0.03696455806493759
#
# Start of epoch 8
# Training loss (for one batch) at step 0: 0.03996208310127258
# Training loss (for one batch) at step 100: 0.03281622380018234
#
# Start of epoch 9
# Training loss (for one batch) at step 0: 0.03319031000137329
# Training loss (for one batch) at step 100: 0.029667027294635773
#
# Start of epoch 10
# Training loss (for one batch) at step 0: 0.03377668559551239
# Training loss (for one batch) at step 100: 0.03125699982047081
#
# Start of epoch 11
# Training loss (for one batch) at step 0: 0.03177574276924133
# Training loss (for one batch) at step 100: 0.03299371525645256
#
# Start of epoch 12
# Training loss (for one batch) at step 0: 0.03185010328888893
# Training loss (for one batch) at step 100: 0.02958097495138645
#
# Start of epoch 13
# Training loss (for one batch) at step 0: 0.028649482876062393
# Training loss (for one batch) at step 100: 0.028892267495393753
#
# Start of epoch 14
# Training loss (for one batch) at step 0: 0.027845723554491997
# Training loss (for one batch) at step 100: 0.02939516119658947
#
# Start of epoch 15
# Training loss (for one batch) at step 0: 0.02958451211452484
# Training loss (for one batch) at step 100: 0.02739766612648964
#
# Start of epoch 16
# Training loss (for one batch) at step 0: 0.028050484135746956
# Training loss (for one batch) at step 100: 0.026631711050868034
#
# Start of epoch 17
# Training loss (for one batch) at step 0: 0.027257820591330528
# Training loss (for one batch) at step 100: 0.02558956854045391
#
# Start of epoch 18
# Training loss (for one batch) at step 0: 0.024792145937681198
# Training loss (for one batch) at step 100: 0.026046374812722206
#
# Start of epoch 19
# Training loss (for one batch) at step 0: 0.02458425611257553
# Training loss (for one batch) at step 100: 0.023810744285583496
#
# Start of epoch 20
# Training loss (for one batch) at step 0: 0.024428315460681915
# Training loss (for one batch) at step 100: 0.024639269337058067
#
# Start of epoch 21
# Training loss (for one batch) at step 0: 0.02271730825304985
# Training loss (for one batch) at step 100: 0.024040386080741882
#
# Start of epoch 22
# Training loss (for one batch) at step 0: 0.023052897304296494
# Training loss (for one batch) at step 100: 0.024756532162427902
#
# Start of epoch 23
# Training loss (for one batch) at step 0: 0.024004820734262466
# Training loss (for one batch) at step 100: 0.02326972410082817
#
# Start of epoch 24
# Training loss (for one batch) at step 0: 0.02449497953057289
# Training loss (for one batch) at step 100: 0.024135403335094452
#
# Start of epoch 25
# Training loss (for one batch) at step 0: 0.022374356165528297
# Training loss (for one batch) at step 100: 0.02217188850045204
#
# Start of epoch 26
# Training loss (for one batch) at step 0: 0.022963736206293106
# Training loss (for one batch) at step 100: 0.022503094747662544
#
# Start of epoch 27
# Training loss (for one batch) at step 0: 0.022355739027261734
# Training loss (for one batch) at step 100: 0.021602440625429153
#
# Start of epoch 28
# Training loss (for one batch) at step 0: 0.022416800260543823
# Training loss (for one batch) at step 100: 0.022048266604542732
#
# Start of epoch 29
# Training loss (for one batch) at step 0: 0.02247878909111023
# Training loss (for one batch) at step 100: 0.02195734903216362
#
# Start of epoch 30
# Training loss (for one batch) at step 0: 0.022419843822717667
# Training loss (for one batch) at step 100: 0.02135077491402626
#
# Start of epoch 31
# Training loss (for one batch) at step 0: 0.02333337999880314
# Training loss (for one batch) at step 100: 0.02215004712343216
#
# Start of epoch 32
# Training loss (for one batch) at step 0: 0.023165496066212654
# Training loss (for one batch) at step 100: 0.020785177126526833
#
# Start of epoch 33
# Training loss (for one batch) at step 0: 0.021161528304219246
# Training loss (for one batch) at step 100: 0.020444625988602638
#
# Start of epoch 34
# Training loss (for one batch) at step 0: 0.021067705005407333
# Training loss (for one batch) at step 100: 0.021848557516932487
#
# Start of epoch 35
# Training loss (for one batch) at step 0: 0.021752336993813515
# Training loss (for one batch) at step 100: 0.020562367513775826
#
# Start of epoch 36
# Training loss (for one batch) at step 0: 0.02166757546365261
# Training loss (for one batch) at step 100: 0.02037975937128067
#
# Start of epoch 37
# Training loss (for one batch) at step 0: 0.02056959457695484
# Training loss (for one batch) at step 100: 0.019791394472122192
#
# Start of epoch 38
# Training loss (for one batch) at step 0: 0.021097781136631966
# Training loss (for one batch) at step 100: 0.021044885739684105
#
# Start of epoch 39
# Training loss (for one batch) at step 0: 0.021375132724642754
# Training loss (for one batch) at step 100: 0.019416239112615585
#
# Start of epoch 40
# Training loss (for one batch) at step 0: 0.019823528826236725
# Training loss (for one batch) at step 100: 0.02053931914269924
#
# Start of epoch 41
# Training loss (for one batch) at step 0: 0.020707257091999054
# Training loss (for one batch) at step 100: 0.019779663532972336
#
# Start of epoch 42
# Training loss (for one batch) at step 0: 0.021253589540719986
# Training loss (for one batch) at step 100: 0.019918292760849
#
# Start of epoch 43
# Training loss (for one batch) at step 0: 0.021238766610622406
# Training loss (for one batch) at step 100: 0.02042403817176819
#
# Start of epoch 44
# Training loss (for one batch) at step 0: 0.019913099706172943
# Training loss (for one batch) at step 100: 0.019548682495951653
#
# Start of epoch 45
# Training loss (for one batch) at step 0: 0.020510472357273102
# Training loss (for one batch) at step 100: 0.019041480496525764
#
# Start of epoch 46
# Training loss (for one batch) at step 0: 0.020100340247154236
# Training loss (for one batch) at step 100: 0.018704228103160858
#
# Start of epoch 47
# Training loss (for one batch) at step 0: 0.02068139798939228
# Training loss (for one batch) at step 100: 0.01932789757847786
#
# Start of epoch 48
# Training loss (for one batch) at step 0: 0.019337903708219528
# Training loss (for one batch) at step 100: 0.02045529894530773
#
# Start of epoch 49
# Training loss (for one batch) at step 0: 0.019270051270723343
# Training loss (for one batch) at step 100: 0.019274836406111717
#
# Start of epoch 50
# Training loss (for one batch) at step 0: 0.019373418763279915
# Training loss (for one batch) at step 100: 0.018489403650164604
#
# Start of epoch 51
# Training loss (for one batch) at step 0: 0.01897597499191761
# Training loss (for one batch) at step 100: 0.020323310047388077
#
# Start of epoch 52
# Training loss (for one batch) at step 0: 0.019181277602910995
# Training loss (for one batch) at step 100: 0.019374776631593704
#
# Start of epoch 53
# Training loss (for one batch) at step 0: 0.019488630816340446
# Training loss (for one batch) at step 100: 0.01944667287170887
#
# Start of epoch 54
# Training loss (for one batch) at step 0: 0.019053105264902115
# Training loss (for one batch) at step 100: 0.021066520363092422
#
# Start of epoch 55
# Training loss (for one batch) at step 0: 0.019851477816700935
# Training loss (for one batch) at step 100: 0.01911219209432602
#
# Start of epoch 56
# Training loss (for one batch) at step 0: 0.019374746829271317
# Training loss (for one batch) at step 100: 0.019101295620203018
#
# Start of epoch 57
# Training loss (for one batch) at step 0: 0.019004857167601585
# Training loss (for one batch) at step 100: 0.018617164343595505
#
# Start of epoch 58
# Training loss (for one batch) at step 0: 0.01883130706846714
# Training loss (for one batch) at step 100: 0.01884906366467476
#
# Start of epoch 59
# Training loss (for one batch) at step 0: 0.018648097291588783
# Training loss (for one batch) at step 100: 0.01887422427535057
#
# Start of epoch 60
# Training loss (for one batch) at step 0: 0.018800973892211914
# Training loss (for one batch) at step 100: 0.019395383074879646
#
# Start of epoch 61
# Training loss (for one batch) at step 0: 0.01988443359732628
# Training loss (for one batch) at step 100: 0.01867745816707611
#
# Start of epoch 62
# Training loss (for one batch) at step 0: 0.018994109705090523
# Training loss (for one batch) at step 100: 0.019435584545135498
#
# Start of epoch 63
# Training loss (for one batch) at step 0: 0.019283197820186615
# Training loss (for one batch) at step 100: 0.018481381237506866
#
# Start of epoch 64
# Training loss (for one batch) at step 0: 0.01938609406352043
# Training loss (for one batch) at step 100: 0.018858661875128746
#
# Start of epoch 65
# Training loss (for one batch) at step 0: 0.018857982009649277
# Training loss (for one batch) at step 100: 0.018646743148565292
#
# Start of epoch 66
# Training loss (for one batch) at step 0: 0.0188961923122406
# Training loss (for one batch) at step 100: 0.018420211970806122
#
# Start of epoch 67
# Training loss (for one batch) at step 0: 0.019341588020324707
# Training loss (for one batch) at step 100: 0.018502939492464066
#
# Start of epoch 68
# Training loss (for one batch) at step 0: 0.018896741792559624
# Training loss (for one batch) at step 100: 0.018804388120770454
#
# Start of epoch 69
# Training loss (for one batch) at step 0: 0.018846753984689713
# Training loss (for one batch) at step 100: 0.01864457316696644
#
# Start of epoch 70
# Training loss (for one batch) at step 0: 0.018750349059700966
# Training loss (for one batch) at step 100: 0.0187058188021183
#
# Start of epoch 71
# Training loss (for one batch) at step 0: 0.019130319356918335
# Training loss (for one batch) at step 100: 0.018552254885435104
#
# Start of epoch 72
# Training loss (for one batch) at step 0: 0.018336493521928787
# Training loss (for one batch) at step 100: 0.01841062121093273
#
# Start of epoch 73
# Training loss (for one batch) at step 0: 0.018753474578261375
# Training loss (for one batch) at step 100: 0.018309928476810455
#
# Start of epoch 74
# Training loss (for one batch) at step 0: 0.018923699855804443
# Training loss (for one batch) at step 100: 0.018355250358581543
#
# Start of epoch 75
# Training loss (for one batch) at step 0: 0.018892422318458557
# Training loss (for one batch) at step 100: 0.018192630261182785
#
# Start of epoch 76
# Training loss (for one batch) at step 0: 0.019283290952444077
# Training loss (for one batch) at step 100: 0.01833692379295826
#
# Start of epoch 77
# Training loss (for one batch) at step 0: 0.01867971196770668
# Training loss (for one batch) at step 100: 0.018516596406698227
#
# Start of epoch 78
# Training loss (for one batch) at step 0: 0.018878916278481483
# Training loss (for one batch) at step 100: 0.01849384605884552
#
# Start of epoch 79
# Training loss (for one batch) at step 0: 0.01844005472958088
# Training loss (for one batch) at step 100: 0.01832304149866104
#
# Start of epoch 80
# Training loss (for one batch) at step 0: 0.018548952415585518
# Training loss (for one batch) at step 100: 0.01804172992706299
#
# Start of epoch 81
# Training loss (for one batch) at step 0: 0.0184426698833704
# Training loss (for one batch) at step 100: 0.01855659671127796
#
# Start of epoch 82
# Training loss (for one batch) at step 0: 0.018485194072127342
# Training loss (for one batch) at step 100: 0.018435610458254814
#
# Start of epoch 83
# Training loss (for one batch) at step 0: 0.018780352547764778
# Training loss (for one batch) at step 100: 0.018142886459827423
#
# Start of epoch 84
# Training loss (for one batch) at step 0: 0.018663151189684868
# Training loss (for one batch) at step 100: 0.018188703805208206
#
# Start of epoch 85
# Training loss (for one batch) at step 0: 0.01816445216536522
# Training loss (for one batch) at step 100: 0.017953990027308464
#
# Start of epoch 86
# Training loss (for one batch) at step 0: 0.01899113692343235
# Training loss (for one batch) at step 100: 0.01845153607428074
#
# Start of epoch 87
# Training loss (for one batch) at step 0: 0.018604520708322525
# Training loss (for one batch) at step 100: 0.01850181445479393
#
# Start of epoch 88
# Training loss (for one batch) at step 0: 0.018633628264069557
# Training loss (for one batch) at step 100: 0.018094366416335106
#
# Start of epoch 89
# Training loss (for one batch) at step 0: 0.01852528005838394
# Training loss (for one batch) at step 100: 0.018616745248436928
#
# Start of epoch 90
# Training loss (for one batch) at step 0: 0.01880529895424843
# Training loss (for one batch) at step 100: 0.018119104206562042
#
# Start of epoch 91
# Training loss (for one batch) at step 0: 0.018699534237384796
# Training loss (for one batch) at step 100: 0.017857864499092102
#
# Start of epoch 92
# Training loss (for one batch) at step 0: 0.018574897199869156
# Training loss (for one batch) at step 100: 0.01791723072528839
#
# Start of epoch 93
# Training loss (for one batch) at step 0: 0.018490247428417206
# Training loss (for one batch) at step 100: 0.017901701852679253
#
# Start of epoch 94
# Training loss (for one batch) at step 0: 0.01811870187520981
# Training loss (for one batch) at step 100: 0.01803041435778141
#
# Start of epoch 95
# Training loss (for one batch) at step 0: 0.01859418861567974
# Training loss (for one batch) at step 100: 0.01806706190109253
#
# Start of epoch 96
# Training loss (for one batch) at step 0: 0.01811940409243107
# Training loss (for one batch) at step 100: 0.01801994815468788
#
# Start of epoch 97
# Training loss (for one batch) at step 0: 0.018255366012454033
# Training loss (for one batch) at step 100: 0.018026746809482574
#
# Start of epoch 98
# Training loss (for one batch) at step 0: 0.0185621939599514
# Training loss (for one batch) at step 100: 0.01815889962017536
#
# Start of epoch 99
# Training loss (for one batch) at step 0: 0.017819898203015327
# Training loss (for one batch) at step 100: 0.01792404241859913
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# /usr/local/lib/python3.12/dist-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %% [markdown]
# **How I understand the code**
#
# The code loads CIFAR-10 and normalize it, then turn the training images into a TensorFlow dataset. A small CNN (“encoder”) turns each 32×32 image into a 128 dimensional vector, and a “projection head” maps that to another 128-D space. For SimCLR training, each batch is augmented and passed through the encoder+head. And then L2-normalize those vectors, compute all pairs cosine similarities, divide by a temperature, and apply a contrastive (InfoNCE) loss so augmented views of the same image end up close while different images push apart. After training, the code is run the encoder on test images and plot a 2-D t-SNE scatter, coloring points by their true class to see how well the representation clusters.
#
# **The Result**
#
# During training the reported batch loss steadily fell—from about 5.19 at the very start (epoch 0, step 0) down to the ~0.018–0.019 range by the later epochs, showing the model was learning a representation where positive pairs align and negatives separate. Afterward, the notebook generates the t-SNE plot of the learned test set embeddings, colored by CIFAR-10 labels, to visually assess class separation.
